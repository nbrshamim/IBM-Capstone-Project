# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Histogram**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will focus on the visualization of data. The dataset will be provided through an RDBMS, and you will need to use SQL queries to extract the required data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Visualize the distribution of data using histograms.
#
# - Visualize relationships between features.
#
# - Explore data composition and comparisons.

# %% [markdown]
# ## Demo: Working with database

# %% [markdown]
# #### Download the database file.

# %%
# !wget -O survey-data.sqlite https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite

# %%
# url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite"

# %% [markdown]
# #### Install the required libraries and import them

# %%
# %pip install wget
# Out:
# Requirement already satisfied: wget in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import wget
# url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite"
# filename = wget.download(url)
# print(f"Downloaded file: {filename}")

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Connect to the SQLite database

# %%
conn = sqlite3.connect('survey-results-public.sqlite')

# %% [markdown]
# ## Demo: Basic SQL queries
#
# **Demo 1: Count the number of rows in the table**

# %%
QUERY = "SELECT COUNT(*) FROM main"
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(*)
# 0     65437

# %% [markdown]
# **Demo 2: List all tables**

# %%
QUERY = """
SELECT name as Table_Name 
FROM sqlite_master 
WHERE type = 'table'
"""
pd.read_sql_query(QUERY, conn)
# Out:
#   Table_Name
# 0       main

# %% [markdown]
# **Demo 3: Group data by age**

# %%
QUERY = """
SELECT Age, COUNT(*) as count 
FROM main 
GROUP BY Age 
ORDER BY Age
"""
df_age = pd.read_sql_query(QUERY, conn)
print(df_age)
# Out:
#                   Age  count
# 0     18-24 years old  14098
# 1     25-34 years old  23911
# 2     35-44 years old  14942
# 3     45-54 years old   6249
# 4     55-64 years old   2575
# 5   65 years or older    772
# 6   Prefer not to say    322
# 7  Under 18 years old   2568

# %% [markdown]
# ## Hands-on Lab: Visualizing Data with Histograms

# %% [markdown]
# ### 1. Visualizing the distribution of data (Histograms)

# %% [markdown]
# **1.1 Histogram of `CompTotal` (Total Compensation)**

# %% [markdown]
# Objective: Plot a histogram of `CompTotal` to visualize the distribution of respondents' total compensation.

# %%
## Write your code here
query = """
select CompTotal from main"""
df_comp = pd.read_sql_query(query,conn)
print(df_comp)
# Out:
#        CompTotal
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 65432        NaN
# 65433        NaN
# 65434        NaN
# 65435        NaN
# 65436        NaN
#
# [65437 rows x 1 columns]

# %%
df_comp.dropna()
# Out:
#        CompTotal
# 72     2040000.0
# 374      28000.0
# 379      85000.0
# 385      50000.0
# 389     110000.0
# ...          ...
# 65396    36000.0
# 65401    40000.0
# 65408    61000.0
# 65412    58000.0
# 65431    55000.0
#
# [33740 rows x 1 columns]

# %%
q1 = df_comp['CompTotal'].quantile(0.25)
q3 = df_comp['CompTotal'].quantile(0.75)

iqr = q3-q1
lower_bound = q1-1.5*iqr
upper_bound = q1+1.5*iqr

df_comp_no_outlier = df_comp[(df_comp['CompTotal'] >= lower_bound) & (df_comp['CompTotal'] <= upper_bound)]

# %%
import seaborn as sns

plt.figure(figsize = (12,6))
sns.histplot(df_comp_no_outlier['CompTotal'], bins=30, kde=True)
plt.title('Histogram distribution of Total Compensation')
# Out:
# Text(0.5, 1.0, 'Histogram distribution of Total Compensation')

# %% [markdown]
# **1.2 Histogram of YearsCodePro (Years of Professional Coding Experience)**

# %% [markdown]
# Objective: Plot a histogram of `YearsCodePro` to analyze the distribution of coding experience among respondents.

# %%
## Write your code here
query = """ select YearsCodePro from main """
df_exp = pd.read_sql_query(query,conn)
df_exp
# Out:
#       YearsCodePro
# 0              NaN
# 1               17
# 2               27
# 3              NaN
# 4              NaN
# ...            ...
# 65432            3
# 65433          NaN
# 65434            5
# 65435            2
# 65436          NaN
#
# [65437 rows x 1 columns]

# %%
df_exp = df_exp.dropna(subset='YearsCodePro')
df_exp
# Out:
#       YearsCodePro
# 1               17
# 2               27
# 6                7
# 9               11
# 11              25
# ...            ...
# 65428            7
# 65431           24
# 65432            3
# 65434            5
# 65435            2
#
# [51610 rows x 1 columns]

# %%
df_exp = df_exp.replace({'Less than 1 year':0, 'More than 50 years':51})

# %%
print(df_exp['YearsCodePro'].unique())
# Out:
# ['17' '27' '7' '11' '25' '12' '10' '3' 0 '18' '37' '15' '20' '6' '2' '16'
#  '8' '14' '4' '45' '1' '24' '29' '5' '30' '26' '9' '33' '13' '35' '23'
#  '22' '31' '19' '21' '28' '34' '32' '40' '50' '39' '44' '42' '41' '36'
#  '38' 51 '43' '47' '48' '46' '49']

# %%
df_exp['YearsCodePro'].dtypes
# Out:
# dtype('O')

# %%
df_exp.astype('float')
# Out:
#        YearsCodePro
# 1              17.0
# 2              27.0
# 6               7.0
# 9              11.0
# 11             25.0
# ...             ...
# 65428           7.0
# 65431          24.0
# 65432           3.0
# 65434           5.0
# 65435           2.0
#
# [51610 rows x 1 columns]

# %%
df_exp['YearsCodePro'].dtypes
# Out:
# dtype('O')

# %%
df_exp['YearsCodePro'] = pd.to_numeric(df_exp['YearsCodePro'], errors='coerce')

# %%
df_exp['YearsCodePro'].dtypes
# Out:
# dtype('int64')

# %%
plt.figure(figsize = (12,6))
sns.histplot(df_exp['YearsCodePro'], bins=30, kde=True)
plt.title('Histogram distribution of Coding experience')
# Out:
# Text(0.5, 1.0, 'Histogram distribution of Coding experience')

# %% [markdown]
# ### 2. Visualizing Relationships in Data

# %% [markdown]
# **2.1 Histogram Comparison of `CompTotal` by `Age` Group**

# %% [markdown]
# Objective: Use histograms to compare the distribution of CompTotal across different Age groups.

# %%
## Write your code here
QUERY = """SELECT CompTotal, Age from main"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#    CompTotal                 Age
# 0        NaN  Under 18 years old
# 1        NaN     35-44 years old
# 2        NaN     45-54 years old
# 3        NaN     18-24 years old
# 4        NaN     18-24 years old

# %%
df['CompTotal'].isnull().sum()
# Out:
# np.int64(31697)

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_comp = df.dropna(subset='CompTotal')

# %%
df_comp.value_counts()
# Out:
# CompTotal  Age
# 60000.0    25-34 years old    374
# 100000.0   25-34 years old    365
# 50000.0    25-34 years old    321
# 120000.0   25-34 years old    303
# 100000.0   35-44 years old    302
#                              ...
# 254600.0   35-44 years old      1
# 247433.0   35-44 years old      1
# 1690000.0  25-34 years old      1
# 157000.0   45-54 years old      1
# 77700.0    25-34 years old      1
# Name: count, Length: 5590, dtype: int64

# %%
Q1 = df_comp['CompTotal'].quantile(0.25)
Q3 = df_comp['CompTotal'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR
df_comp_no_outlier = df_comp[(df_comp['CompTotal']>= lower_bound) & (df_comp['CompTotal']<= upper_bound)]

# %%
df_comp_no_outlier.value_counts()
# Out:
# CompTotal  Age
# 60000.0    25-34 years old    374
# 100000.0   25-34 years old    365
# 50000.0    25-34 years old    321
# 120000.0   25-34 years old    303
# 100000.0   35-44 years old    302
#                              ...
# 2520.0     18-24 years old      1
# 254600.0   35-44 years old      1
# 247433.0   35-44 years old      1
# 157000.0   45-54 years old      1
# 77700.0    25-34 years old      1
# Name: count, Length: 3794, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df_comp_no_outlier, x='CompTotal', hue='Age', multiple='stack', bins=30, kde=True)
plt.title('Distribution of CompTotal Across Age Groups')
plt.xlabel('CompTotal')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **2.2 Histogram of TimeSearching for Different Age Groups**

# %% [markdown]
# Objective: Use histograms to explore the distribution of `TimeSearching` (time spent searching for information) for respondents across different age groups.

# %%
## Write your code here
## Write your code here
QUERY = """SELECT TimeSearching, Age from main"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#   TimeSearching                 Age
# 0           NaN  Under 18 years old
# 1           NaN     35-44 years old
# 2           NaN     45-54 years old
# 3           NaN     18-24 years old
# 4           NaN     18-24 years old

# %%
df['TimeSearching'].isnull().sum()
# Out:
# np.int64(36526)

# %%
df_time_search = df.dropna(subset='TimeSearching')

# %%
df_time_search['TimeSearching'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_time_search['TimeSearching'].value_counts()
# Out:
# TimeSearching
# 30-60 minutes a day           10951
# 15-30 minutes a day            7805
# 60-120 minutes a day           5275
# Less than 15 minutes a day     2689
# Over 120 minutes a day         2191
# Name: count, dtype: int64

# %%
# Step 1: Define the order of categories
time_order = ['Less than 15 minutes a day', '15-30 minutes a day', '30-60 minutes a day', '60-120 minutes a day','Over 120 minutes a day']
df_time_search = df_time_search.copy()
# Step 2: Convert to categorical type with the specified order
df_time_search['TimeSearching'] = pd.Categorical(df_time_search['TimeSearching'], categories=time_order, ordered=True)

# %%
plt.figure(figsize = (10,6))
sns.histplot(df_time_search, x = 'TimeSearching', hue = 'Age',multiple='stack', palette = 'deep')
plt.title('Distribution of TimeSearching across different age groups')
plt.xlabel('Time searching')
plt.ylabel('Frequency')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### 3. Visualizing the Composition of Data

# %% [markdown]
# **3.1 Histogram of Most Desired Databases (`DatabaseWantToWorkWith`)**

# %% [markdown]
# Objective: Visualize the most desired databases for future learning using a histogram of the top 5 databases.

# %%
## Write your code here
## Write your code here
QUERY = """SELECT DatabaseWantToWorkWith from main"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#        DatabaseWantToWorkWith
# 0                         NaN
# 1                  PostgreSQL
# 2  Firebase Realtime Database
# 3    MongoDB;MySQL;PostgreSQL
# 4           PostgreSQL;SQLite

# %%
df.isnull().sum()
# Out:
# DatabaseWantToWorkWith    22879
# dtype: int64

# %%
df_db_want = df.dropna(subset = 'DatabaseWantToWorkWith')

# %%
df_db_want.isnull().sum()
# Out:
# DatabaseWantToWorkWith    0
# dtype: int64

# %%
df_db_want['Db_want_count'] = df_db_want['DatabaseWantToWorkWith'].str.split(';').str.len()
df_db_want['Db_want_count']
# Out:
# 1         1
# 2         1
# 3         3
# 4         2
# 5         1
#          ..
# 65421     1
# 65427    14
# 65431     3
# 65435     2
# 65436     3
# Name: Db_want_count, Length: 42558, dtype: int64

# %%
df_db_want = df_db_want.copy()
df_db_want = df_db_want[df_db_want['Db_want_count']<=5]

# %%
df_db_want['DatabaseWantToWorkWith']
# Out:
# 1                            PostgreSQL
# 2            Firebase Realtime Database
# 3              MongoDB;MySQL;PostgreSQL
# 4                     PostgreSQL;SQLite
# 5                       Cloud Firestore
#                       ...
# 65414                         Cassandra
# 65421                          Dynamodb
# 65431    Elasticsearch;PostgreSQL;Redis
# 65435                 PostgreSQL;SQLite
# 65436          MongoDB;MySQL;PostgreSQL
# Name: DatabaseWantToWorkWith, Length: 38129, dtype: str

# %%
from collections import Counter
# !pip install matplotlib-venn
from matplotlib_venn import venn2
# Out:
# Requirement already satisfied: matplotlib-venn in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.1.2)
# Requirement already satisfied: matplotlib in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib-venn) (3.11.0)
# Requirement already satisfied: numpy in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib-venn) (2.5.0)
# Requirement already satisfied: scipy in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib-venn) (1.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Shamim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
db_want_count = Counter(df_db_want['DatabaseWantToWorkWith'].str.split(';').explode().str.strip())

# %%
db_want_count
# Out:
# Counter({'PostgreSQL': 20234,
#          'SQLite': 10894,
#          'MySQL': 9469,
#          'MongoDB': 8086,
#          'Redis': 7886,
#          'Microsoft SQL Server': 6432,
#          'MariaDB': 4202,
#          'Elasticsearch': 3978,
#          'Dynamodb': 2215,
#          'Supabase': 1971,
#          'Oracle': 1781,
#          'BigQuery': 1565,
#          'Firebase Realtime Database': 1455,
#          'Cloud Firestore': 1270,
#          'Cassandra': 1130,
#          'Cosmos DB': 1107,
#          'Snowflake': 1070,
#          'DuckDB': 989,
#          'Neo4J': 859,
#          'Clickhouse': 839,
#          'Databricks SQL': 706,
#          'InfluxDB': 636,
#          'H2': 599,
#          'Cockroachdb': 584,
#          'Microsoft Access': 385,
#          'Solr': 286,
#          'Datomic': 254,
#          'Couch DB': 249,
#          'Firebird': 233,
#          'IBM DB2': 192,
#          'EventStoreDB': 146,
#          'Presto': 129,
#          'Couchbase': 129,
#          'TiDB': 103,
#          'RavenDB': 78})

# %%
df_db_want_count = pd.DataFrame(db_want_count.items(), columns = ['DataBase', 'Db_counts'])

# %%
df_db_want_count.head()
# Out:
#                      DataBase  Db_counts
# 0                  PostgreSQL      20234
# 1  Firebase Realtime Database       1455
# 2                     MongoDB       8086
# 3                       MySQL       9469
# 4                      SQLite      10894

# %%
top5_db = df_db_want_count.sort_values('Db_counts', ascending=False).head(5)

# %%
top5_db
# Out:
#      DataBase  Db_counts
# 0  PostgreSQL      20234
# 4      SQLite      10894
# 3       MySQL       9469
# 2     MongoDB       8086
# 7       Redis       7886

# %%
plt.figure(figsize = (8,6))
sns.barplot(top5_db, x='DataBase', y='Db_counts')
# Out:
# <Axes: xlabel='DataBase', ylabel='Db_counts'>

# %% [markdown]
# **3.2 Histogram of Preferred Work Locations (`RemoteWork`)**

# %% [markdown]
# Objective: Use a histogram to explore the distribution of preferred work arrangements (`remote work`).

# %%
## Write your code here
## Write your code here
QUERY = """SELECT RemoteWork from main"""
df = pd.read_sql_query(QUERY, conn)

# %%
df.isnull().sum()
# Out:
# RemoteWork    10631
# dtype: int64

# %%
df_re = df.dropna(subset = 'RemoteWork')

# %%
df_re.isnull().sum()
# Out:
# RemoteWork    0
# dtype: int64

# %%
df_re.value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    23015
# Remote                                  20831
# In-person                               10960
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.histplot(df_re, x='RemoteWork')
plt.title('Distribution of prefered work arrangement')
plt.show()

# %% [markdown]
# ### 4. Visualizing Comparison of Data

# %% [markdown]
# **4.1 Histogram of Median CompTotal for Ages 45 to 60**

# %% [markdown]
# Objective: Plot the histogram for `CompTotal` within the age group 45 to 60 to analyze compensation distribution among mid-career respondents.

# %%
## Write your code here
## Write your code here
# use df_comp_no_outlier above which contain no outlier for compensation
group_age = (['45-54 years old', '55-64 years old'])
df_comp_age_45_64 = df_comp_no_outlier[df_comp_no_outlier['Age'].isin(group_age)]

# %%
plt.figure(figsize = (8,6))
sns.histplot(df_comp_age_45_64, x='CompTotal', hue='Age', bins = 30, alpha = 0.5, multiple = 'stack')
plt.title('Distribution of prefered work arrangement')
plt.show()

# %% [markdown]
# **4.2 Histogram of Job Satisfaction (`JobSat`) by YearsCodePro**

# %% [markdown]
# Objective: Plot the histogram for `JobSat` scores based on respondents' years of professional coding experience.

# %%
## Write your code here
## Write your code here
QUERY = """SELECT YearsCodePro, JobSat from main"""
df = pd.read_sql_query(QUERY, conn)

# %%
df['YearsCodePro'].isnull().sum()
# Out:
# np.int64(13827)

# %%
df_sat_year = df.dropna(subset = ['YearsCodePro', 'JobSat'])

# %%
df_sat_year['YearsCodePro'].replace({'Less than 1 year': 0, 'More than 50 years': 51})
# Out:
# 12       12
# 15       27
# 18       10
# 20        0
# 22       18
#          ..
# 65178    17
# 65241    10
# 65265     2
# 65351     7
# 65412    18
# Name: YearsCodePro, Length: 28356, dtype: object

# %%
df_sat_year['JobSat'].value_counts()
# Out:
# JobSat
# 8.0     7325
# 7.0     6243
# 6.0     3651
# 9.0     3557
# 10.0    2196
# 5.0     1869
# 3.0     1141
# 4.0     1097
# 2.0      736
# 0.0      284
# 1.0      257
# Name: count, dtype: int64

# %%
df_sat_year = df_sat_year.copy()
df_sat_year['JobSat_recode'] = df_sat_year['JobSat'].replace({0: 'Very unsatisfied',
                               1: 'Very unsatisfied',
                               2: 'Very unsatisfied',
                               3: 'Unsatisfied',
                               4: 'Unsatisfied',
                               5: 'Neutral',
                               6: 'Neutral',
                               7: 'Satisfied',
                               8: 'Satisfied',
                               9: 'Very satisfied',
                               10: 'Very satisfied'})

# %%
df_sat_year
# Out:
#            YearsCodePro  JobSat   JobSat_recode
# 12                   12     8.0       Satisfied
# 15                   27     5.0         Neutral
# 18                   10    10.0  Very satisfied
# 20     Less than 1 year     6.0         Neutral
# 22                   18     9.0  Very satisfied
# ...                 ...     ...             ...
# 65178                17     8.0       Satisfied
# 65241                10     5.0         Neutral
# 65265                 2     8.0       Satisfied
# 65351                 7     8.0       Satisfied
# 65412                18     8.0       Satisfied
#
# [28356 rows x 3 columns]

# %%
df_sat_year['YearsCodePro'] = pd.to_numeric(df_sat_year['YearsCodePro'], errors='coerce')

# %%
plt.figure(figsize = (12, 6))
sns.histplot(df_sat_year, x='YearsCodePro', hue='JobSat_recode', bins = 30, multiple='stack', palette = 'deep')
# Out:
# <Axes: xlabel='YearsCodePro', ylabel='Count'>

# %% [markdown]
# ### Final step: Close the database connection

# %% [markdown]
# Once you've completed the lab, make sure to close the connection to the SQLite database:

# %%
conn.close()

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you used histograms to visualize various aspects of the dataset, focusing on:
#
# - Distribution of compensation, coding experience, and work hours.
#
# - Relationships in compensation across age groups and work status.
#
# - Composition of data by desired databases and work environments.
#
# - Comparisons of job satisfaction across years of experience.
#
# Histograms helped reveal patterns and distributions in the data, enhancing your understanding of developer demographics and preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
